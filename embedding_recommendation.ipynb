# %%
import numpy as np
import pandas as pd
import re

# %%
#clean reviews
def docs_to_word_list(series):
  return series.map(lambda x: re.findall('\w+', x.lower()))

# %% [markdown]
# # Document Similarity Using Word Embedding

# %%
attributes = ['citrus', 'tropical', 'hops']
reviews = pd.read_csv('beer_reviews.csv')[['name', 'review']]

# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_md

# %%
import spacy
nlp = spacy.load("en_core_web_md")
import en_core_web_md
nlp = en_core_web_md.load()
# remove generic beer words
stopwords = set(['beer', 'brew', 'ale', 'mead'])
reviews.loc[:, 'split_review'] = reviews.review.map(lambda x: re.findall('\w+', x.lower()))
reviews.loc[:, 'split_review'] = reviews.split_review.map(lambda x: [word for word in x if word not in stopwords])
reviews.loc[:, 'review'] = reviews.split_review.map(lambda x: ' '.join(x))

attr_vector = nlp(' '.join(attributes))
reviews['embedding_score'] = reviews.review.map(lambda x: nlp(x).similarity(attr_vector))
reviews.head()
# Out:
# <ipython-input-6-7687fdac9cc1>:11: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   reviews['embedding_score'] = reviews.review.map(lambda x: nlp(x).similarity(attr_vector))
#                           name  \
# 0  Kentucky Brunch Brand Stout
# 1  Kentucky Brunch Brand Stout
# 2  Kentucky Brunch Brand Stout
# 3  Kentucky Brunch Brand Stout
# 4  Kentucky Brunch Brand Stout
#
#                                               review  \
# 0  so ok on the real i gave up a ton for a couple...
# 1  poured into a snifter glass a dark chocolaty c...
# 2  if there s any that deserves the rating of a 5...
# 3  this has been on my bucket list for a while th...
# 4  i didnt think i was going to give it a perfect...
#
#                                         split_review  embedding_score
# 0  [so, ok, on, the, real, i, gave, up, a, ton, f...         0.325409
# 1  [poured, into, a, snifter, glass, a, dark, cho...         0.542600
# 2  [if, there, s, any, that, deserves, the, ratin...         0.346571
# 3  [this, has, been, on, my, bucket, list, for, a...         0.335161
# 4  [i, didnt, think, i, was, going, to, give, it,...         0.418328

# %%
reviews.sort_values(by='embedding_score', ascending=False, inplace=True)
reviews.head()
# Out:
#                               name  \
# 2304               Triple Sunshine
# 614         Double Barrel V.S.O.J.
# 568                         Clover
# 5467  Cellarman Barrel Aged Saison
# 3392    Dorothy (Wine Barrel Aged)
#
#                                                  review  \
# 2304  aroma big and sweet tropical fruit smell pinea...
# 614   boozy concentrated sweet drippy raisins figs d...
# 568   golden yellow pour miniscule head white wine o...
# 5467  the aroma offers apricot tart stone fruit oak ...
# 3392  gold pour hazy larger head white wine grape oa...
#
#                                            split_review  embedding_score
# 2304  [aroma, big, and, sweet, tropical, fruit, smel...         0.743084
# 614   [boozy, concentrated, sweet, drippy, raisins, ...         0.740573
# 568   [golden, yellow, pour, miniscule, head, white,...         0.713571
# 5467  [the, aroma, offers, apricot, tart, stone, fru...         0.701120
# 3392  [gold, pour, hazy, larger, head, white, wine, ...         0.693241

# %% [markdown]
# # Sentiment Analysis Using Vader

# %%
# !pip install vaderSentiment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
vader = SentimentIntensityAnalyzer()
#adding context
newWords = {'bitter': 0.75, 'hoppy': 1, 'opaque': 1, 'sour': 1.5, 'boozy': -2, 'alcohol': -2}
vader.lexicon.update(newWords)

reviews.loc[:, 'sentiment'] = reviews.review.map(lambda x: vader.polarity_scores(x)['compound'])
reviews.head()
# Out:
#                               name  \
# 2304               Triple Sunshine
# 614         Double Barrel V.S.O.J.
# 568                         Clover
# 5467  Cellarman Barrel Aged Saison
# 3392    Dorothy (Wine Barrel Aged)
#
#                                                  review  \
# 2304  aroma big and sweet tropical fruit smell pinea...
# 614   boozy concentrated sweet drippy raisins figs d...
# 568   golden yellow pour miniscule head white wine o...
# 5467  the aroma offers apricot tart stone fruit oak ...
# 3392  gold pour hazy larger head white wine grape oa...
#
#                                            split_review  embedding_score  \
# 2304  [aroma, big, and, sweet, tropical, fruit, smel...         0.743084
# 614   [boozy, concentrated, sweet, drippy, raisins, ...         0.740573
# 568   [golden, yellow, pour, miniscule, head, white,...         0.713571
# 5467  [the, aroma, offers, apricot, tart, stone, fru...         0.701120
# 3392  [gold, pour, hazy, larger, head, white, wine, ...         0.693241
#
#       sentiment
# 2304     0.5245
# 614      0.5574
# 568      0.8910
# 5467     0.0000
# 3392     0.0000

# %%
# evenly weighed recommendation score
reviews['recommendation_score'] = reviews.embedding_score * reviews.sentiment
output = reviews[['name', 'embedding_score', 'sentiment', 'recommendation_score']].groupby(by=['name']).mean()
output.sort_values(by='recommendation_score', ascending=False, inplace=True)
output.head()
# Out:
#                              embedding_score  sentiment  recommendation_score
# name
# Beyond Good And Evil                0.429560   0.769594              0.361542
# Coconut Vibes - Barrel-Aged         0.475621   0.719117              0.350645
# Framboise Du Fermier                0.420520   0.779404              0.337857
# Double Galaxy                       0.436009   0.728540              0.331849
# Montmorency Vs Balaton              0.434994   0.710213              0.326149

# %% [markdown]
# # Our Recommendation
# Based on your preferences for a citrus-y, tropical, hoppy beer, we have three brews for you to try out. All three should be somewhere in the ballpark given your exact tasting notes and are as follows:
# 1. "Beyond Good and Evil"
# 2. "Coconut Vibes - Barrel-Aged"
# 3. "Framboise Du Fermier"
#
# Keep in mind that our current recommendation model is based on similarity between your sought after attributes and others' reviews, so it will yield robust recommendations that will be somewhere in the range of your interests, but may not be an exact match.

# %%
from collections import defaultdict
# represent reviews as a vector of 3 chosen attributes
def word2vec(words, attributes):
  word_counts = defaultdict(int)
  for word in words:
    if word in attributes:
      word_counts[word] += 1
  result = np.array([word_counts[key] for key in attributes]).reshape(1, -1)
  return result

# %%
reviews.loc[:, 'attr_vector'] = reviews.split_review.map(lambda x: word2vec(x, attributes))

# %% [markdown]
# ##### Checking top 3 recommendations for keyword attributes...

# %%
reviews[reviews.name == 'Beyond Good And Evil']
# Out:
#                       name                                             review  \
# 2753  Beyond Good And Evil  smells like hot buttered rum and coffee liquor...
# 2759  Beyond Good And Evil  2014 batch enjoyed in 2017 and it was still am...
# 2749  Beyond Good And Evil  fantastic dark brown to black appearance aroma...
# 2760  Beyond Good And Evil  wow just wow big chewy chocolate covered raisi...
# 2748  Beyond Good And Evil  quite possibly the best stout i have ever had ...
# 2754  Beyond Good And Evil  2018 version poured from the bottle into a sni...
# 2752  Beyond Good And Evil  maple explosion 20 months in barrel makes it s...
# 2758  Beyond Good And Evil  drank 5 1 15 loads of sweet thick maple syrup ...
# 2764  Beyond Good And Evil  how is this not higher on the list this is lit...
# 2755  Beyond Good And Evil  quite possibly the perfect ba stout in my mind...
# 2756  Beyond Good And Evil  quite possibly the best i have ever had the ma...
# 2761  Beyond Good And Evil  major maple flavor explosion going on in my mo...
# 2757  Beyond Good And Evil  had a chance to try this at a bottle share whi...
# 2763  Beyond Good And Evil                        amazing stout not too sweet
# 2750  Beyond Good And Evil  a perfect ba maple stout had on site at hf was...
# 2747  Beyond Good And Evil  this truly is beyond good and evil everything ...
# 2762  Beyond Good And Evil       bottle shared by yourefragile thanks michael
# 2751  Beyond Good And Evil                                       date 4 28 14
#
#                                            split_review  embedding_score  \
# 2753  [smells, like, hot, buttered, rum, and, coffee...         0.647103
# 2759  [2014, batch, enjoyed, in, 2017, and, it, was,...         0.612021
# 2749  [fantastic, dark, brown, to, black, appearance...         0.558311
# 2760  [wow, just, wow, big, chewy, chocolate, covere...         0.533682
# 2748  [quite, possibly, the, best, stout, i, have, e...         0.528424
# 2754  [2018, version, poured, from, the, bottle, int...         0.515935
# 2752  [maple, explosion, 20, months, in, barrel, mak...         0.510729
# 2758  [drank, 5, 1, 15, loads, of, sweet, thick, map...         0.501211
# 2764  [how, is, this, not, higher, on, the, list, th...         0.463713
# 2755  [quite, possibly, the, perfect, ba, stout, in,...         0.432684
# 2756  [quite, possibly, the, best, i, have, ever, ha...         0.429615
# 2761  [major, maple, flavor, explosion, going, on, i...         0.416845
# 2757  [had, a, chance, to, try, this, at, a, bottle,...         0.368408
# 2763                  [amazing, stout, not, too, sweet]         0.367945
# 2750  [a, perfect, ba, maple, stout, had, on, site, ...         0.342412
# 2747  [this, truly, is, beyond, good, and, evil, eve...         0.332371
# 2762  [bottle, shared, by, yourefragile, thanks, mic...         0.163137
# 2751                                  [date, 4, 28, 14]         0.007534
#
#       sentiment  recommendation_score  attr_vector
# 2753     0.9639              0.623742  [[0, 0, 0]]
# 2759     0.9797              0.599597  [[0, 0, 0]]
# 2749     0.9717              0.542510  [[0, 0, 0]]
# 2760     0.9657              0.515377  [[0, 0, 0]]
# 2748     0.9765              0.516006  [[0, 0, 0]]
# 2754     0.8860              0.457118  [[0, 0, 0]]
# 2752     0.5994              0.306131  [[0, 0, 0]]
# 2758     0.9551              0.478707  [[0, 0, 0]]
# 2764     0.8402              0.389612  [[0, 0, 0]]
# 2755     0.8993              0.389113  [[0, 0, 0]]
# 2756     0.8824              0.379092  [[0, 0, 0]]
# 2761     0.7050              0.293876  [[0, 0, 0]]
# 2757     0.8016              0.295316  [[0, 0, 0]]
# 2763     0.4624              0.170138  [[0, 0, 0]]
# 2750     0.8442              0.289064  [[0, 0, 0]]
# 2747     0.4710              0.156547  [[0, 0, 0]]
# 2762     0.6486              0.105811  [[0, 0, 0]]
# 2751     0.0000              0.000000  [[0, 0, 0]]

# %%
reviews[reviews.name == 'Coconut Vibes - Barrel-Aged']
# Out:
#                             name  \
# 352  Coconut Vibes - Barrel-Aged
# 348  Coconut Vibes - Barrel-Aged
# 355  Coconut Vibes - Barrel-Aged
# 349  Coconut Vibes - Barrel-Aged
# 356  Coconut Vibes - Barrel-Aged
# 358  Coconut Vibes - Barrel-Aged
# 351  Coconut Vibes - Barrel-Aged
# 353  Coconut Vibes - Barrel-Aged
# 357  Coconut Vibes - Barrel-Aged
# 350  Coconut Vibes - Barrel-Aged
# 359  Coconut Vibes - Barrel-Aged
# 354  Coconut Vibes - Barrel-Aged
#
#                                                 review  \
# 352  pours pitch black wafts of sweet coconut choco...
# 348  pours a deep dark brown basically opaque but a...
# 355  750ml white wax bottle served into a snifter g...
# 349  thick gooey delicious just tastes magnificent ...
# 356  i never thought i d get to try this it was pre...
# 358  pours thick and viscous upfront chocolate coco...
# 351  super thick awesome coconut the whole way and ...
# 353  pours thick black with little coconut floaties...
# 357  first review and stout in a minute in the proc...
# 350  this is right up there with my perfect beers i...
# 359  i kinda wish there was more toasted coconut an...
# 354  look outstanding black thick with a really nic...
#
#                                           split_review  embedding_score  \
# 352  [pours, pitch, black, wafts, of, sweet, coconu...         0.627514
# 348  [pours, a, deep, dark, brown, basically, opaqu...         0.541340
# 355  l, white, wax, bottle, served, into, a, s...         0.519573
# 349  [thick, gooey, delicious, just, tastes, magnif...         0.502010
# 356  [i, never, thought, i, d, get, to, try, this, ...         0.468160
# 358  [pours, thick, and, viscous, upfront, chocolat...         0.457144
# 351  [super, thick, awesome, coconut, the, whole, w...         0.449195
# 353  [pours, thick, black, with, little, coconut, f...         0.448796
# 357  [first, review, and, stout, in, a, minute, in,...         0.428742
# 350  [this, is, right, up, there, with, my, perfect...         0.427229
# 359  [i, kinda, wish, there, was, more, toasted, co...         0.424176
# 354  [look, outstanding, black, thick, with, a, rea...         0.413578
#
#      sentiment  recommendation_score  attr_vector
# 352     0.8655              0.543113  [[0, 0, 0]]
# 348     0.8641              0.467771  [[0, 0, 0]]
# 355     0.9832              0.510844  [[0, 0, 0]]
# 349     0.9765              0.490213  [[0, 0, 0]]
# 356     0.6124              0.286701  [[0, 0, 0]]
# 358     0.8984              0.410698  [[0, 0, 0]]
# 351     0.9477              0.425702  [[0, 0, 0]]
# 353     0.9861              0.442558  [[0, 0, 0]]
# 357     0.5627              0.241253  [[0, 0, 0]]
# 350     0.5423              0.231686  [[0, 0, 0]]
# 359    -0.4055             -0.172003  [[0, 0, 0]]
# 354     0.7960              0.329208  [[0, 0, 0]]

# %%
reviews[reviews.name == 'Framboise Du Fermier']
# Out:
#                      name                                             review  \
# 946  Framboise Du Fermier  deep purplish red color very nice carb level a...
# 953  Framboise Du Fermier  deep red color and nice thick head well carbed...
# 950  Framboise Du Fermier  pouted from a 750 ml bottle the color is very ...
# 956  Framboise Du Fermier  wow absolutely fantastic deep ruby red magenta...
# 947  Framboise Du Fermier  this was one of my top three from the 2015 hf ...
# 957  Framboise Du Fermier  the nose on this was absolutely incredible hug...
# 960  Framboise Du Fermier  part of a share in pittsburgh pours deep red w...
# 944  Framboise Du Fermier  the perfect don t drink too cold once it warms...
# 959  Framboise Du Fermier  fresh picked raspberry on the nose fresh but m...
# 964  Framboise Du Fermier  l pours a bright ruby red that recedes into a ...
# 943  Framboise Du Fermier  cory brought out a bottle at he fermier releas...
# 963  Framboise Du Fermier  easily the best i ve ever had from side projec...
# 961  Framboise Du Fermier  can t help but notice the beautiful color of t...
# 966  Framboise Du Fermier  750ml bottle generously shared by erik poured ...
# 952  Framboise Du Fermier  some of side projects finest had this alongsid...
# 965  Framboise Du Fermier  first of all the smell wow hits your nose and ...
# 962  Framboise Du Fermier  probably one of the best smelling beers that i...
# 958  Framboise Du Fermier  shared from a 750 at the cellar a beautiful wi...
# 951  Framboise Du Fermier  pours an absolutely gorgeous ruby red with a p...
# 955  Framboise Du Fermier  poured from a bottle into a fw snifter 4oz pou...
# 945  Framboise Du Fermier  tasted multiple times at the festival of farmh...
# 948  Framboise Du Fermier  compared to framboos 14 and lpf 11 this was my...
# 967  Framboise Du Fermier  incredible so happy my buddy brought one out a...
# 954  Framboise Du Fermier  compared to framboos 14 and lpf 11 this beat both
# 949  Framboise Du Fermier                        wow wow wow just simply wow
#
#                                           split_review  embedding_score  \
# 946  [deep, purplish, red, color, very, nice, carb,...         0.546333
# 953  [deep, red, color, and, nice, thick, head, wel...         0.507825
# 950  [pouted, from, a, 750, ml, bottle, the, color,...         0.506388
# 956  [wow, absolutely, fantastic, deep, ruby, red, ...         0.499747
# 947  [this, was, one, of, my, top, three, from, the...         0.496688
# 957  [the, nose, on, this, was, absolutely, incredi...         0.490110
# 960  [part, of, a, share, in, pittsburgh, pours, de...         0.476617
# 944  [the, perfect, don, t, drink, too, cold, once,...         0.475761
# 959  [fresh, picked, raspberry, on, the, nose, fres...         0.472014
# 964  [l, pours, a, bright, ruby, red, that, recedes...         0.462837
# 943  [cory, brought, out, a, bottle, at, he, fermie...         0.436977
# 963  [easily, the, best, i, ve, ever, had, from, si...         0.432079
# 961  [can, t, help, but, notice, the, beautiful, co...         0.429554
# 966  l, bottle, generously, shared, by, erik, ...         0.414250
# 952  [some, of, side, projects, finest, had, this, ...         0.413352
# 965  [first, of, all, the, smell, wow, hits, your, ...         0.413175
# 962  [probably, one, of, the, best, smelling, beers...         0.407314
# 958  [shared, from, a, 750, at, the, cellar, a, bea...         0.397876
# 951  [pours, an, absolutely, gorgeous, ruby, red, w...         0.394964
# 955  [poured, from, a, bottle, into, a, fw, snifter...         0.367168
# 945  [tasted, multiple, times, at, the, festival, o...         0.357799
# 948  [compared, to, framboos, 14, and, lpf, 11, thi...         0.353160
# 967  [incredible, so, happy, my, buddy, brought, on...         0.342669
# 954  [compared, to, framboos, 14, and, lpf, 11, thi...         0.216566
# 949                 [wow, wow, wow, just, simply, wow]         0.201784
#
#      sentiment  recommendation_score  attr_vector
# 946     0.9398              0.513444  [[0, 0, 0]]
# 953     0.9333              0.473953  [[0, 0, 0]]
# 950     0.9493              0.480714  [[0, 0, 0]]
# 956     0.9647              0.482106  [[0, 0, 0]]
# 947     0.8957              0.444883  [[0, 0, 0]]
# 957     0.7674              0.376110  [[0, 0, 0]]
# 960     0.9795              0.466846  [[0, 0, 0]]
# 944     0.9694              0.461202  [[0, 0, 0]]
# 959     0.5187              0.244834  [[0, 0, 0]]
# 964     0.7096              0.328429  [[0, 0, 0]]
# 943     0.9042              0.395115  [[0, 0, 0]]
# 963     0.9517              0.411210  [[0, 0, 0]]
# 961     0.9904              0.425430  [[0, 0, 0]]
# 966     0.8176              0.338691  [[0, 0, 0]]
# 952     0.6808              0.281410  [[0, 0, 0]]
# 965     0.9532              0.393839  [[0, 0, 0]]
# 962     0.8241              0.335667  [[0, 0, 0]]
# 958     0.9538              0.379494  [[0, 0, 0]]
# 951     0.6478              0.255857  [[0, 0, 0]]
# 955     0.0000              0.000000  [[0, 0, 0]]
# 945     0.4939              0.176717  [[0, 0, 0]]
# 948     0.8481              0.299515  [[0, 0, 0]]
# 967     0.8470              0.290241  [[0, 0, 0]]
# 954     0.0000              0.000000  [[0, 0, 0]]
# 949     0.9451              0.190706  [[0, 0, 0]]

# %% [markdown]
# # Embeddings vs. Cosine Similarity
#
# Looking at our output using SpaCy for embeddings, we were able to get some higher similarity scores to recommend for our customer. However, looking at the above counts of the actual attributes requested, we can see that NO reviews out of the top 3 beers had *any* mention of the attributes!
#
# When trying to recommend products as specific as beer, it is probably better to use regular cosine similarity to look for exact matches. With word embeddings, words can be categorized as being "similar" due to appearing in similar contexts, rather than actually having similar characterstics. This phenomenon might be model-dependent, and modern LLMs may have fixed this issue, but using a library like SpaCy certainly had this limitation. For example, words like "coconut" have high similarity with "tropical," which normally would be great, but in the niche world of beer, those two lead to very different flavors.
#
# Furthermore, before manually removing words such as "beer," we saw high document similarity with reviews that read as "amazing beer" because of beer's high similarity with a word like "hops."
#
# Due to all these reasons, we believe cosine similarity is preferable for a beer review system, while word embeddings are much better in a more general sense (i.e. product recommendations on Amazon).

# %% [markdown]
# # Task G

# %%
top_prods = reviews[['name', 'sentiment', 'embedding_score']].groupby(by=['name']).mean()
top_prods.sort_values(by='sentiment', ascending=False, inplace=True)
top_prods.head()
# Out:
#                         sentiment  embedding_score
# name
# Double Sunshine          0.787810         0.408408
# Everett                  0.783767         0.352177
# Framboise Du Fermier     0.779404         0.420520
# Beyond Good And Evil     0.769594         0.429560
# Cutting Tiles - Mosaic   0.748735         0.410941

# %%
top_fits = reviews[['name', 'sentiment', 'embedding_score']].groupby(by=['name']).mean()
top_fits.sort_values(by='embedding_score', ascending=False, inplace=True)
top_fits.head()
# Out:
#                                     sentiment  embedding_score
# name
# Saison Du Fermier                    0.604560         0.476699
# Coconut Vibes - Barrel-Aged          0.719117         0.475621
# Monster Tones                        0.529267         0.465605
# La Fosse                             0.390630         0.456108
# Speedway Stout - Vietnamese Coffee   0.700700         0.448298

# %% [markdown]
# By looking at the above tables, we can see there is no overlap between the top sentiments and top similarity scores. If we were to grab the 3 highest rated beers in terms of sentiment as our recommendation, we wouldn't have had the best results, but they also would not have been terrible. "Beyond Good and Evil," our top beer based on a combination of sentiment and similarity, still made the top 5 in terms of sentiment. Additionally, the top rated beer would not have been a *bad* choice, as it was only .04 away in similarity from the 5th best score in terms of similarity.
#
# >Unrelated, but we once again see the shortcomings of word embeddings in the context of beer here - a stout is curiously the 5th best match for someone who enjoys hoppy, citrusy beers.

# %% [markdown]
# ### Now looking at ratings...

# %%
ratings = pd.read_csv('beer_reviews.csv')[['name', 'rating']]
ratings.head()
# Out:
#                           name  rating
# 0  Kentucky Brunch Brand Stout     5.0
# 1  Kentucky Brunch Brand Stout     5.0
# 2  Kentucky Brunch Brand Stout     5.0
# 3  Kentucky Brunch Brand Stout     5.0
# 4  Kentucky Brunch Brand Stout     5.0

# %%
grouped_beers = ratings.groupby('name').agg({'rating': ['count', 'mean']})
grouped_beers.sort_values([('rating','mean'),('rating','count')], ascending = False)
# Out:
#                                                    rating
#                                                     count      mean
# name
# Heady Topper                                           46  5.000000
# Breakfast Stout                                        43  5.000000
# Pliny The Elder                                        41  5.000000
# KBS                                                    37  5.000000
# Green                                                  36  5.000000
# ...                                                   ...       ...
# Truth                                                  16  4.530625
# Label Us Notorious - Calvados BA Big Poppa              7  4.520000
# Leaner                                                 17  4.511765
# Starry Noche                                           40  4.505500
# Bourbon County Brand Two-Year Barleywine Reserv...     32  4.471250
#
# [249 rows x 2 columns]

# %%
top_beers = top_fits[(top_fits.index == 'Heady Topper') | (top_fits.index == 'Breakfast Stout') | (top_fits.index == 'Pliny The Elder')]
top_beers.sort_values(by='embedding_score', ascending=False, inplace=True)
top_beers.head()
# Out:
# <ipython-input-22-7e1bf6c08946>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_beers.sort_values(by='embedding_score', ascending=False, inplace=True)
#                  sentiment  embedding_score
# name
# Pliny The Elder   0.654861         0.383352
# Heady Topper      0.596035         0.383337
# Breakfast Stout   0.660802         0.365951

# %% [markdown]
# When we do the analysis on the top three beers, we can see that they have lower similarity scores for the actual attributes we're looking for. Due to this, they may not be the best match. None of these top beers are in the top embedding or sentiment scores. While we believe cosine is better than embedding, we believe embedding is still better than just offering the top 3 rated beers due to the difference in characteristics.
#
# In summary, even though this may be the top 3 beers in ratings, they don't necessarily align with the attributes that the customer will be looking for.

# %% [markdown]
# # Task H

# %%
grouped_beers.sort_values([('rating','count'),('rating','mean')], ascending = False, inplace=True)
grouped_beers
# Out:
#                                       rating
#                                        count      mean
# name
# Kaggen! Stormaktsporter                   75  4.765333
# Yellow Bus                                66  4.590758
# KBS - Maple Mackinac Fudge                58  4.926897
# BDCS                                      48  4.843333
# CitraQuench'l                             48  4.792500
# ...                                      ...       ...
# §ucaba                                     4  5.000000
# Beatification                              3  5.000000
# Ephraim                                    3  5.000000
# Everett                                    3  5.000000
# Fourth Dementia - Bourbon Barrel-Aged      2  5.000000
#
# [249 rows x 2 columns]

# %%
#from csv
top_attributes = ['dark', 'chocolate', 'bourbon', 'coffee']
top_attribute_freqs = {'dark': 789, 'chocolate': 771, 'bourbon': 636, 'coffee': 608}
chosen_beers = list(grouped_beers.index[0:10])

# %%
# brand to attribute co-occurences
chosen_brands_reviews = reviews[reviews.name.isin(chosen_beers)]
chosen_brands_reviews.loc[:, 'attr_counts'] = chosen_brands_reviews.split_review.map(lambda x: word2vec(x, top_attributes))
chosen_brands_reviews.loc[:, 'dark'] = chosen_brands_reviews.attr_counts.map(lambda x: x[0][0])
chosen_brands_reviews.loc[:, 'chocolate'] = chosen_brands_reviews.attr_counts.map(lambda x: x[0][1])
chosen_brands_reviews.loc[:, 'bourbon'] = chosen_brands_reviews.attr_counts.map(lambda x: x[0][2])
chosen_brands_reviews.loc[:, 'coffee'] = chosen_brands_reviews.attr_counts.map(lambda x: x[0][3])
coc_df = chosen_brands_reviews[['name','dark', 'chocolate', 'bourbon', 'coffee']].groupby('name').sum()
coc_df
# Out:
# <ipython-input-25-a78cb2eac645>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chosen_brands_reviews.loc[:, 'attr_counts'] = chosen_brands_reviews.split_review.map(lambda x: word2vec(x, top_attributes))
# <ipython-input-25-a78cb2eac645>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chosen_brands_reviews.loc[:, 'dark'] = chosen_brands_reviews.attr_counts.map(lambda x: x[0][0])
# <ipython-input-25-a78cb2eac645>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chosen_brands_reviews.loc[:, 'chocolate'] = chosen_brands_reviews.attr_counts.map(lambda x: x[0][1])
# <ipython-input-25-a78cb2eac645>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chosen_brands_reviews.loc[:, 'bourbon'] = chosen_brands_reviews.attr_counts.map(lambda x: x[0][2])
# <ipython-input-25-a78cb2eac645>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chosen_brands_reviews.loc[:, 'coffee'] = chosen_brands_reviews.attr_counts.map(lambda x: x[0][3])
#                             dark  chocolate  bourbon  coffee
# name
# Ann                            1          0        0       0
# BDCS                          19         16       29       4
# Breakfast Stout                4         15        1      21
# CitraQuench'l                  0          0        0       0
# Heady Topper                   0          0        0       0
# KBS - Maple Mackinac Fudge    17         46       21      27
# Kaggen! Stormaktsporter       18         24        6       9
# Pliny The Elder                0          0        0       0
# The Rusty Nail                10          6        8       1
# Yellow Bus                     0          0        0       0

# %%
# calculate the lifts between attributes and the top 10 brands
attr_lifts = coc_df.copy()

# iterate through df rows and columns
for i, row in attr_lifts.iterrows():
  for j in attr_lifts.columns:
    # get number of co-occurrences from the df_attr_coc dataframe
    coc = attr_lifts.loc[i, j]

    # get the count of each attribute j from the attribute frequency dataframe
    attr_count = top_attribute_freqs[j]
    # get the brand count from the top 10 brand count dataframe from before
    brand_count = grouped_beers[grouped_beers.index == i][('rating', 'count')][0]
    # lift formula
    attr_lifts.loc[i, j] = (5553*coc) / (attr_count * brand_count)
print('Lifts:')
attr_lifts
# Out:
# Lifts:
#                                 dark  chocolate   bourbon    coffee
# name
# Ann                         0.159955   0.000000  0.000000  0.000000
# BDCS                        2.785884   2.400778  5.275059  0.761102
# Breakfast Stout             0.654700   2.512442  0.203050  4.460412
# CitraQuench'l               0.000000   0.000000  0.000000  0.000000
# Heady Topper                0.000000   0.000000  0.000000  0.000000
# KBS - Maple Mackinac Fudge  2.062869   5.712196  3.161272  4.251673
# Kaggen! Stormaktsporter     1.689125   2.304747  0.698491  1.095987
# Pliny The Elder             0.000000   0.000000  0.000000  0.000000
# The Rusty Nail              1.636749   1.004977  1.624397  0.212401
# Yellow Bus                  0.000000   0.000000  0.000000  0.000000

# %%
# choosing Kaggen! Stormaktsporter, using OLS to see least different beer
def square_error(col):
  ref = col[col.index == 'Kaggen! Stormaktsporter'].values[0]
  return col.apply(lambda x: (x - ref)**2)
sq_error_df = attr_lifts.apply(square_error, axis=0)
sq_error_df.loc[:, 'sum'] = sq_error_df.sum(axis=1)
sq_error_df.sort_values(by=['sum'], inplace=True)
sq_error_df
# Out:
#                                 dark  chocolate    bourbon     coffee  \
# name
# Kaggen! Stormaktsporter     0.000000   0.000000   0.000000   0.000000
# The Rusty Nail              0.002743   1.689402   0.857302   0.780725
# Ann                         2.338362   5.311859   0.487889   1.201187
# CitraQuench'l               2.853145   5.311859   0.487889   1.201187
# Heady Topper                2.853145   5.311859   0.487889   1.201187
# Pliny The Elder             2.853145   5.311859   0.487889   1.201187
# Yellow Bus                  2.853145   5.311859   0.487889   1.201187
# Breakfast Stout             1.070036   0.043137   0.245462  11.319354
# BDCS                        1.202879   0.009222  20.944978   0.112148
# KBS - Maple Mackinac Fudge  0.139684  11.610711   6.065292   9.958356
#
#                                   sum
# name
# Kaggen! Stormaktsporter      0.000000
# The Rusty Nail               3.330173
# Ann                          9.339297
# CitraQuench'l                9.854080
# Heady Topper                 9.854080
# Pliny The Elder              9.854080
# Yellow Bus                   9.854080
# Breakfast Stout             12.677989
# BDCS                        22.269227
# KBS - Maple Mackinac Fudge  27.774043

# %% [markdown]
# # Most Similar Beer
#
# For our analysis, we chose "Kaggen! Stormaktsporter" as our beer to compare others to. After analysing the difference in lifts using squared errors, we can see by our table that "The Rusty Nail" is the most similar beer.
