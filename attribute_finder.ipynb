# %%
import re
import numpy as np
import pandas as pd

# %%
reviews = pd.read_csv('beer_reviews.csv')

# %%
# clean reviews
words_list = reviews.review.map(lambda x: re.findall('\w+', x.lower()))
words = np.concatenate(words_list)

# %%
words_list
# Out:
# 0       [so, ok, on, the, real, i, gave, up, a, ton, f...
# 1       [poured, into, a, snifter, glass, a, dark, cho...
# 2       [if, there, s, any, beer, that, deserves, the,...
# 3       [this, brew, has, been, on, my, bucket, list, ...
# 4       [i, didnt, think, i, was, going, to, give, it,...
#                               ...
# 5548                        [look, dark, not, too, thick]
# 5549                                        [great, quad]
# 5550    [look, dark, amber, little, head, short, lived...
# 5551    [i, ve, had, the, delight, of, both, the, 2014...
# 5552                   [2015, is, my, personal, favorite]
# Name: review, Length: 5553, dtype: object

# %%
# perform count of all words
from collections import Counter
counter = Counter(words)
# convert counter to dataframe for calculations and manipulation
word_counts_df = pd.DataFrame.from_dict(counter, orient='index').reset_index()
word_counts_df.rename(columns={'index': 'Word', 0: 'Frequency'}, inplace=True)
word_counts_df.head()
word_counts_df.to_csv('word_frequencies.csv')

# %%
# chosen by reviewing csv
attribute_candidates = ['dark', 'chocolate', 'bourbon', 'coffee', 'vanilla', 'sweet', 'thick', 'orange', 'smooth', 'fruit', 'coconut', 'light', 'maple', 'hazy', 'balanced', 'creamy', 'rich', 'oak', 'citrus', 'sour', 'sweetness', 'juice', 'cinnamon', 'caramel', 'tropical', 'aged', 'peach', 'hop', 'golden', 'juicy', 'hops']

# %%
df_coc = pd.DataFrame(columns=list(attribute_candidates), index=list(attribute_candidates))
df_coc.fillna(0, inplace=True)

# copy of df_coc to ensure that an interaction is only counted once per message
df_coc_counts = df_coc.copy()

# %%
# iterate through messages where the models have been replaced with the brands
for message in words_list:
  # reset the interaction DF to 0 to retrack interactions for each new message
  df_coc_counts.iloc[:] = 0
  for i, word in enumerate(message):
    if word in attribute_candidates:
      # if another mention of a brand is within 20 words, count it as an interaction
      for j in range(20):
        # check that the index is still within the length of the message
        if i+j+1 in range(len(message)):
          # check if a different brand is mentioned in the range, not the same brand capture before, and not already logged as an interaction in the interaction dataframe
          if message[i+j+1] in attribute_candidates and message[i+j+1] != word and df_coc_counts.loc[word][message[i+j+1]] < 1:
            # update both dfs, counting number of interactions in total, logging an interaction
            df_coc.loc[word][message[i+j+1]] += 1
            df_coc.loc[message[i+j+1]][word] += 1
            df_coc_counts.loc[word][message[i+j+1]] = 1
            df_coc_counts.loc[message[i+j+1]][word] = 1

df_coc

# %%
# copy over brand co-occurrences dataframe to calculate lifts
lifts = df_coc.copy()

# %%
# calculate lifts
for i in lifts:
  # each i value is one of the top 10 brands
  # find the count for the ith brand in the top10 brands df
  b1_df = word_counts_df[word_counts_df['Word'] == i]
  # this gets the count using iloc
  b1 = b1_df['Frequency'].iloc[0]
  for j in lifts:
    # get the other count for the jth brand that brand i is co-occurring with
    b2_df = word_counts_df[word_counts_df['Word'] == j]
    b2 = b2_df['Frequency'].iloc[0]
    # calculating the lift for the i and j brands
    # number of comments: 5553 * co-occurrences of brand i and j OVER
    # product of the count of brands i and j
    lifts.loc[i, j] = (lifts.loc[i, j]*5553)/(b1*b2)

lifts_display = lifts.copy()

for i in range(len(lifts_display.columns)):
  for j in range(i, len(lifts_display)):
    lifts_display.iloc[i, j] = np.nan

lifts_display = lifts_display.T
lifts_display
# Out:
#            dark  chocolate   bourbon    coffee   vanilla     sweet     thick  \
# dark        NaN   1.734715  1.571665  1.261978  1.526905  1.188978  1.388227
# chocolate   NaN        NaN  2.299272  2.310375  2.489490  1.534747  1.463686
# bourbon     NaN        NaN       NaN  1.407574  2.777128  1.592336  1.374270
# coffee      NaN        NaN       NaN       NaN  1.847124  1.595534  0.964438
# vanilla     NaN        NaN       NaN       NaN       NaN  1.998800  1.220266
# sweet       NaN        NaN       NaN       NaN       NaN       NaN  1.295371
# thick       NaN        NaN       NaN       NaN       NaN       NaN       NaN
# orange      NaN        NaN       NaN       NaN       NaN       NaN       NaN
# smooth      NaN        NaN       NaN       NaN       NaN       NaN       NaN
# fruit       NaN        NaN       NaN       NaN       NaN       NaN       NaN
# coconut     NaN        NaN       NaN       NaN       NaN       NaN       NaN
# light       NaN        NaN       NaN       NaN       NaN       NaN       NaN
# maple       NaN        NaN       NaN       NaN       NaN       NaN       NaN
# hazy        NaN        NaN       NaN       NaN       NaN       NaN       NaN
# balanced    NaN        NaN       NaN       NaN       NaN       NaN       NaN
# creamy      NaN        NaN       NaN       NaN       NaN       NaN       NaN
# rich        NaN        NaN       NaN       NaN       NaN       NaN       NaN
# oak         NaN        NaN       NaN       NaN       NaN       NaN       NaN
# citrus      NaN        NaN       NaN       NaN       NaN       NaN       NaN
# sour        NaN        NaN       NaN       NaN       NaN       NaN       NaN
# sweetness   NaN        NaN       NaN       NaN       NaN       NaN       NaN
# juice       NaN        NaN       NaN       NaN       NaN       NaN       NaN
# cinnamon    NaN        NaN       NaN       NaN       NaN       NaN       NaN
# caramel     NaN        NaN       NaN       NaN       NaN       NaN       NaN
# tropical    NaN        NaN       NaN       NaN       NaN       NaN       NaN
# aged        NaN        NaN       NaN       NaN       NaN       NaN       NaN
# peach       NaN        NaN       NaN       NaN       NaN       NaN       NaN
# hop         NaN        NaN       NaN       NaN       NaN       NaN       NaN
# golden      NaN        NaN       NaN       NaN       NaN       NaN       NaN
# juicy       NaN        NaN       NaN       NaN       NaN       NaN       NaN
# hops        NaN        NaN       NaN       NaN       NaN       NaN       NaN
#
#              orange    smooth     fruit  ...     juice  cinnamon   caramel  \
# dark       0.319968  0.810978  0.954175  ...  0.141493  1.238066  2.465538
# chocolate  0.000000  1.394251  0.589556  ...  0.072398  1.990953  2.193999
# bourbon    0.000000  1.649958  0.647694  ...  0.043883  2.194147  3.058663
# coffee     0.000000  1.494414  0.233628  ...  0.000000  2.387001  1.669316
# vanilla    0.069611  1.270314  0.783342  ...  0.051304  2.770433  3.161335
# sweet      0.726837  1.350956  1.063300  ...  0.964245  1.499937  2.759765
# thick      0.955505  1.045193  0.481032  ...  0.833951  0.889547  1.909479
# orange          NaN  0.698031  1.517310  ...  4.757309  0.000000  0.064075
# smooth          NaN       NaN  0.818238  ...  0.643077  0.900308  1.624015
# fruit           NaN       NaN       NaN  ...  2.426917  0.356900  1.658405
# coconut         NaN       NaN       NaN  ...  0.081607  0.734462  1.154095
# light           NaN       NaN       NaN  ...  0.953432  1.126783  2.013778
# maple           NaN       NaN       NaN  ...  0.000000  2.377154  1.245112
# hazy            NaN       NaN       NaN  ...  2.880986  0.000000  0.090945
# balanced        NaN       NaN       NaN  ...  0.887583  1.380684  1.295080
# creamy          NaN       NaN       NaN  ...  1.061200  0.848960  0.857579
# rich            NaN       NaN       NaN  ...  0.108177  1.081765  2.950419
# oak             NaN       NaN       NaN  ...  0.000000  1.162898  4.111464
# citrus          NaN       NaN       NaN  ...  2.569080  0.000000  0.353886
# sour            NaN       NaN       NaN  ...  0.400616  0.267077  0.000000
# sweetness       NaN       NaN       NaN  ...  0.269657  1.887602  1.225778
# juice           NaN       NaN       NaN  ...       NaN  0.000000  0.141673
# cinnamon        NaN       NaN       NaN  ...       NaN       NaN  1.983420
# caramel         NaN       NaN       NaN  ...       NaN       NaN       NaN
# tropical        NaN       NaN       NaN  ...       NaN       NaN       NaN
# aged            NaN       NaN       NaN  ...       NaN       NaN       NaN
# peach           NaN       NaN       NaN  ...       NaN       NaN       NaN
# hop             NaN       NaN       NaN  ...       NaN       NaN       NaN
# golden          NaN       NaN       NaN  ...       NaN       NaN       NaN
# juicy           NaN       NaN       NaN  ...       NaN       NaN       NaN
# hops            NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#            tropical      aged     peach       hop    golden     juicy  \
# dark       0.037245  0.748861  0.039770  0.159984  0.203448  0.041165
# chocolate  0.038114  0.804661  0.040698  0.245578  0.000000  0.042127
# bourbon    0.092410  1.765121  0.000000  0.198471  0.000000  0.051068
# coffee     0.000000  0.971795  0.000000  0.155708  0.000000  0.000000
# vanilla    0.108038  1.031817  0.230724  0.058009  0.000000  0.059705
# sweet      1.015264  0.453628  0.843185  0.363418  0.246480  0.748089
# thick      0.702460  0.706196  0.250028  0.314311  0.255809  0.647003
# orange     3.940428  0.000000  2.353390  1.075801  3.137441  1.919245
# smooth     1.286495  1.021056  0.578406  1.090673  0.591780  1.421915
# fruit      5.260964  0.453338  1.765544  1.372036  1.067398  2.824307
# coconut    0.257774  1.122963  0.091750  0.092271  0.000000  0.000000
# light      1.368924  0.458735  1.559182  0.490013  1.495530  0.605209
# maple      0.000000  0.465971  0.000000  0.099548  0.000000  0.000000
# hazy       2.938624  0.095299  2.429306  0.916166  5.903002  2.409772
# balanced   2.803635  0.939516  0.997904  1.672623  0.340326  1.262455
# creamy     1.229082  0.898633  0.715860  0.839915  0.732412  1.481956
# rich       0.227800  0.687036  0.364867  0.122313  0.497737  0.251779
# oak        0.244885  0.861658  1.699670  0.394460  1.070135  0.676657
# citrus     5.532975  0.000000  0.919036  3.300922  1.746245  2.853850
# sour       0.140604  0.282704  2.402184  0.000000  0.921647  0.466213
# sweetness  1.419625  0.142718  0.909523  1.067139  0.310184  1.098342
# juice      3.987078  0.000000  2.522897  3.012963  0.645307  2.611420
# cinnamon   0.000000  0.742275  0.000000  0.000000  0.000000  0.000000
# caramel    0.895012  0.299924  0.159282  0.320374  0.000000  0.329741
# tropical        NaN  0.000000  1.162168  2.337542  1.528764  4.124385
# aged            NaN       NaN  0.000000  0.000000  0.170766  0.000000
# peach           NaN       NaN       NaN  0.713148  1.088273  0.917501
# hop             NaN       NaN       NaN       NaN  0.547228  3.875399
# golden          NaN       NaN       NaN       NaN       NaN  0.750972
# juicy           NaN       NaN       NaN       NaN       NaN       NaN
# hops            NaN       NaN       NaN       NaN       NaN       NaN
#
#                hops
# dark       0.124223
# chocolate  0.169497
# bourbon    0.205475
# coffee     0.053735
# vanilla    0.300281
# sweet      0.627075
# thick      0.585728
# orange     1.633529
# smooth     0.903334
# fruit      2.088912
# coconut    0.095528
# light      0.913153
# maple      0.206124
# hazy       1.264668
# balanced   1.154438
# creamy     0.993782
# rich       0.633151
# oak        0.952892
# citrus     4.511002
# sour       0.000000
# sweetness  1.262631
# juice      1.970086
# cinnamon   0.000000
# caramel    0.331681
# tropical   4.667227
# aged       0.173780
# peach      1.476637
# hop        1.670655
# golden     0.566542
# juicy      3.056897
# hops            NaN
#
# [31 rows x 31 columns]
# Warning: Total number of columns (31) exceeds max_columns (20) limiting to first (20) columns.

# %%
from itertools import combinations
# find best combination of 3 lifts
combinations = combinations(attribute_candidates, 3)
avgs = {}
for combination in combinations:
  a1 = combination[0]
  a2 = combination[1]
  a3 = combination[2]
  l1 = lifts.loc[a1, a2]
  l2 = lifts.loc[a1, a3]
  l3 = lifts.loc[a2, a3]
  avg = (l1 + l2 + l3) / 3
  avgs[combination] = avg

# %%
lift_combos_df = pd.DataFrame.from_dict(avgs, orient='index')
lift_combos_df.sort_values(by=0, ascending=False, inplace=True)
lift_combos_df
# Out:
#                                   0
# (citrus, tropical, hops)   4.903734
# (orange, hazy, golden)     4.845812
# (fruit, citrus, tropical)  4.489482
# (orange, hazy, juice)      4.378430
# (orange, juice, tropical)  4.228272
# ...                             ...
# (maple, sour, hop)         0.061126
# (coffee, sour, hops)       0.047050
# (vanilla, sour, hop)       0.035619
# (coconut, sour, hops)      0.031843
# (coconut, sour, hop)       0.030757
#
# [4495 rows x 1 columns]

# %% [markdown]
# Based on the above analysis, we will use "Citrus" "Tropical" and "Hops" as our 3 attributes
